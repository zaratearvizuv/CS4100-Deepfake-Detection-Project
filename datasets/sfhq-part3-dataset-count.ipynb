# %%
import os

def count_images(root_dir):
    count = 0
    for dirpath, _, filenames in os.walk(root_dir):
        for f in filenames:
            if f.endswith(('.jpg', '.png')):
                count += 1
    return count

FAKE_DIR = os.path.join("sfhq-part3", "images", "images")

print("Fake images:", count_images(FAKE_DIR))
# Out:
# Fake images: 118358
