# %%
# counts the flickr-gan-dataset training dataset
import os
TRAIN_FAKE_DIR = os.path.join("flickr-gan-dataset", "real_vs_fake", "real-vs-fake", "train", "fake")
TRAIN_REAL_DIR = os.path.join("flickr-gan-dataset", "real_vs_fake", "real-vs-fake", "train", "real")
TEST_FAKE_DIR = os.path.join("flickr-gan-dataset", "real_vs_fake", "real-vs-fake", "test", "fake")
TEST_REAL_DIR = os.path.join("flickr-gan-dataset", "real_vs_fake", "real-vs-fake", "test", "real")
# Adjust directories above as needed
# print(os.getcwd())
print("Train Real: ", len(os.listdir(TRAIN_REAL_DIR)))
print("Train Fake: ", len(os.listdir(TRAIN_FAKE_DIR)))
print("Test Real: ", len(os.listdir(TEST_REAL_DIR)))
print("Test Fake: ",  len(os.listdir(TEST_FAKE_DIR)))
# Out:
# Train Real:  50000
# Train Fake:  50000
# Test Real:  10000
# Test Fake:  10000
